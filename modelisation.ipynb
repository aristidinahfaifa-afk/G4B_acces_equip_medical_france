# %% [markdown]
# # 3. Modélisation

# %% [markdown]
# ## 3.1 Chargement des données
#
# Nous chargeons ici le fichier fusionné pollen + météo généré lors de l'analyse exploratoire.

# %%
import pandas as pd
import numpy as np

df_pollen_meteo = pd.read_csv("data/raw/df_pollen_meteo_merge.csv", parse_dates=["date"])
print(df_pollen_meteo.shape)
print(df_pollen_meteo.columns.tolist())
df_pollen_meteo.head()
